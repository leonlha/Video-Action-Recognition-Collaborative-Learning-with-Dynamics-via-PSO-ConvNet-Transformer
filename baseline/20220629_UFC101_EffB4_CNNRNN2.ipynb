# %%
from tensorflow_docs.vis import embed
from tensorflow import keras
from imutils import paths

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2
import os

# %%
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 20

MAX_SEQ_LENGTH = 40
NUM_FEATURES = 1792

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

print(f"Total videos for training: {len(train_df)}")
print(f"Total videos for testing: {len(test_df)}")

train_df.sample(10)
# Out:
# Total videos for training: 9537
# Total videos for testing: 3783
#                          video_name              tag
# 6419        v_PoleVault_g09_c01.avi        PoleVault
# 596     v_BaseballPitch_g11_c05.avi    BaseballPitch
# 3841         v_HighJump_g24_c03.avi         HighJump
# 5312        v_Nunchucks_g18_c06.avi        Nunchucks
# 2855  v_FloorGymnastics_g20_c01.avi  FloorGymnastics
# 8112       v_StillRings_g12_c02.avi       StillRings
# 9325      v_WallPushups_g23_c01.avi      WallPushups
# 5679       v_PlayingDaf_g17_c02.avi       PlayingDaf
# 534      v_BandMarching_g19_c05.avi     BandMarching
# 5569     v_PlayingCello_g17_c07.avi     PlayingCello

# %%
# The following two methods are taken from this tutorial:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub


def crop_center_square(frame):
    y, x = frame.shape[0:2]
    min_dim = min(y, x)
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]


def load_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2, 1, 0]]
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

# %%
def build_feature_extractor():
    feature_extractor = keras.applications.EfficientNetB4(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.efficientnet.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()

# %%
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"])
)
print(label_processor.get_vocabulary())

# %%
from tqdm import tqdm

def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()
    labels = df["tag"].values
    labels = label_processor(labels[..., None]).numpy()

    # `frame_masks` and `frame_features` are what we will feed to our sequence model.
    # `frame_masks` will contain a bunch of booleans denoting if a timestep is
    # masked with padding or not.
    frame_masks = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video.
    for idx, path in tqdm(enumerate(video_paths)):
        # Gather all its frames and add a batch dimension.
        frames = load_video(os.path.join(root_dir, path))
        frames = frames[None, ...]

        # Initialize placeholders to store the masks and features of the current video.
        temp_frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video.
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                temp_frame_features[i, j, :] = feature_extractor.predict(
                    batch[None, j, :]
                )
            temp_frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

        frame_features[idx,] = temp_frame_features.squeeze()
        frame_masks[idx,] = temp_frame_mask.squeeze()

    return (frame_features, frame_masks), labels


# train_data, train_labels = prepare_all_videos(train_df, "train")
test_data, test_labels = prepare_all_videos(test_df, "test")

# print(f"Frame features in train set: {train_data[0].shape}")
# print(f"Frame masks in train set: {train_data[1].shape}")

# %%
train_data, train_labels = prepare_all_videos(train_df, "train")

# %%
# Utility for our sequence model.
# Bidirectional

def get_sequence_model():
    class_vocab = label_processor.get_vocabulary()

    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

    # Refer to the following tutorial to understand the significance of using `mask`:
    # https://keras.io/api/layers/recurrent_layers/gru/
    x = keras.layers.Bidirectional(keras.layers.LSTM(2048, return_sequences=False,dropout=0.5))(#16, 512
        frame_features_input, mask=mask_input
    )
#     x = keras.layers.LSTM(2048)(x)#8, 256
#     x = keras.layers.Dropout(0.1)(x)
    x = keras.layers.Dense(1024)(x)#8, 256
    x = keras.layers.LeakyReLU()(x)
    output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

    rnn_model = keras.Model([frame_features_input, mask_input], output)

    rnn_model.compile(
        loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
    )
    return rnn_model


# Utility for running experiments.
def run_experiment():
    filepath = "/tmp/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    seq_model = get_sequence_model()
    print(seq_model.summary())
    
    history = seq_model.fit(
        [train_data[0], train_data[1]],
        train_labels,
        validation_split=0.2,
        epochs=EPOCHS,
        callbacks=[checkpoint],
    )

    seq_model.load_weights(filepath)
    _, accuracy = seq_model.evaluate([test_data[0], test_data[1]], test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, seq_model


_, sequence_model = run_experiment()

# %%
#40.13% LSTM(2048,dropout=0.1)
#46.47% LSTM(2048,dropout=0.5)
#43.96% LSTM(4096,dropout=0.5)

# %%
class_vocab = label_processor.get_vocabulary()

frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

# Refer to the following tutorial to understand the significance of using `mask`:
# https://keras.io/api/layers/recurrent_layers/gru/
x = keras.layers.LSTM(2048, return_sequences=True,dropout=0.1)(#16, 512
    frame_features_input, mask=mask_input
)
#     x = keras.layers.LSTM(2048)(x)#8, 256
#     x = keras.layers.Dropout(0.1)(x)
x = keras.layers.Dense(1024, activation="relu")(x)#8, 256
output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

rnn_model = keras.Model([frame_features_input, mask_input], output)

rnn_model.compile(
    loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
)

print(rnn_model.summary())

# %%
class_vocab = label_processor.get_vocabulary()

frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

# Refer to the following tutorial to understand the significance of using `mask`:
# https://keras.io/api/layers/recurrent_layers/gru/
x = keras.layers.LSTM(2048, return_sequences=False,dropout=0.1)(#16, 512
    frame_features_input, mask=mask_input
)
# x = keras.layers.LSTM(2048)(x)#8, 256
#     x = keras.layers.Dropout(0.1)(x)
x = keras.layers.Dense(1024, activation="relu")(x)#8, 256
output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

rnn_model = keras.Model([frame_features_input, mask_input], output)

rnn_model.compile(
    loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
)

print(rnn_model.summary())

# %%
def prepare_single_video(frames):
    frames = frames[None, ...]
    frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    for i, batch in enumerate(frames):
        video_length = batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            frame_features[i, j, :] = feature_extractor.predict(batch[None, j, :])
        frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

    return frame_features, frame_mask


def sequence_prediction(path):
    class_vocab = label_processor.get_vocabulary()

    frames = load_video(os.path.join("test", path))
    frame_features, frame_mask = prepare_single_video(frames)
    probabilities = sequence_model.predict([frame_features, frame_mask])[0]

    for i in np.argsort(probabilities)[::-1]:
        print(f"  {class_vocab[i]}: {probabilities[i] * 100:5.2f}%")
    return frames


# This utility is for visualization.
# Referenced from:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def to_gif(images):
    converted_images = images.astype(np.uint8)
    imageio.mimsave("animation.gif", converted_images, fps=10)
    return embed.embed_file("animation.gif")


test_video = np.random.choice(test_df["video_name"].values.tolist())
print(f"Test video path: {test_video}")
test_frames = sequence_prediction(test_video)
to_gif(test_frames[:MAX_SEQ_LENGTH])

# %%
ls -l

# %%
import numpy as np
import tensorflow as tf 

np.save('Inception_CNNRNN_train_data.npy', train_data)    # .npy extension is added if not given
# np.save('Inception_CNNRNN_test_data.npy', test_data[0])    # .npy extension is added if not given
# np.save('Inception_CNNRNN_train_labels.npy', train_data[1])    # .npy extension is added if not given
# np.save('Inception_CNNRNN_test_labels.npy', test_labels)    # .npy extension is added if not given

# %%
print(train_data[0].shape)
print(train_data[1].shape)

# %%
print(train_data.type)

# %%
import pickle

with open('EffB4_CNNRNN_train_40.pickle', 'wb') as f:
    pickle.dump(train_data, f)

# %%
import pickle

with open('EffB4_CNNRNN_test_40.pickle', 'wb') as f:
    pickle.dump(test_data, f)

# %%
import numpy as np
import tensorflow as tf 

# np.save('densenet_train_data.npy', train_data)    # .npy extension is added if not given
# np.save('densenet_test_data.npy', test_data)    # .npy extension is added if not given
np.save('CNNRNN_train_labels.npy', train_labels)    # .npy extension is added if not given
np.save('CNNRNN_test_labels.npy', test_labels)    # .npy extension is added if not given

# %%
ls -l

# %%
mv Inception_CNNRNN_20.pickle Inception_CNNRNN_train_20.pickle

# %%
import numpy as np
import tensorflow as tf 
import pickle

with open('EffB4_CNNRNN_train_40.pickle', 'rb') as f:
     d_train_data = pickle.load(f)
with open('EffB4_CNNRNN_test_40.pickle', 'rb') as f:
     d_test_data = pickle.load(f)
        
# d_train_data = np.load('densenet_train_data.npy')
# d_test_data = np.load('densenet_test_data.npy')
d_train_labels = np.load('CNNRNN_train_labels.npy')
d_test_labels = np.load('CNNRNN_test_labels.npy')

# %%
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"])
)
# print(label_processor.get_vocabulary())

def get_sequence_model():
    class_vocab = label_processor.get_vocabulary()

    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

    # Refer to the following tutorial to understand the significance of using `mask`:
    # https://keras.io/api/layers/recurrent_layers/gru/
    x = keras.layers.LSTM(2048, return_sequences=False,dropout=0.5)(#16, 512
        frame_features_input, mask=mask_input
    )    
#     x = keras.layers.Bidirectional(keras.layers.LSTM(2048, return_sequences=False,dropout=0.5),merge_mode='concat')(#16, 512
#         frame_features_input, mask=mask_input
#     )
#     x = keras.layers.LSTM(2048)(x)#8, 256
#     x = keras.layers.Dropout(0.1)(x)
    x = keras.layers.Dense(1024)(x)#8, 256
    x = keras.layers.GaussianNoise(0.4)(x)
    x = keras.layers.LeakyReLU(0.1)(x)    
    output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

    rnn_model = keras.Model([frame_features_input, mask_input], output)

#     rnn_model.compile(
#         loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
#     )
    return rnn_model

# Utility for running experiments.
def d_run_experiment():
    filepath = "/tmp/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    seq_model = get_sequence_model()
    print(seq_model.summary())
    
    optimizer = keras.optimizers.SGD(lr=1e-3)
#     optimizer = keras.optimizers.Adadelta()
    
    seq_model.compile(
        loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"]
    )    
    
    history = seq_model.fit(
        [d_train_data[0], d_train_data[1]],
        d_train_labels,
#         validation_split=0.2,
        validation_data=([d_test_data[0], d_test_data[1]],
        d_test_labels),
        epochs=100,
#         epochs=EPOCHS,
        callbacks=[checkpoint],
    )

    seq_model.load_weights(filepath)
    _, accuracy = seq_model.evaluate([d_test_data[0], d_test_data[1]], d_test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, seq_model


d_run_experiment()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 40, 1792)]   0           []
#
#  input_4 (InputLayer)           [(None, 40)]         0           []
#
#  lstm_1 (LSTM)                  (None, 2048)         31465472    ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  dense_2 (Dense)                (None, 1024)         2098176     ['lstm_1[0][0]']
#
#  gaussian_noise_1 (GaussianNois  (None, 1024)        0           ['dense_2[0][0]']
#  e)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 1024)         0           ['gaussian_noise_1[0][0]']
#
#  dense_3 (Dense)                (None, 101)          103525      ['leaky_re_lu_1[0][0]']
#
# ==================================================================================================
# Total params: 33,667,173
# Trainable params: 33,667,173
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 2022-07-05 22:47:00.444533: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2734448640 exceeds 10% of free system memory.
# 2022-07-05 22:47:02.220610: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2734448640 exceeds 10% of free system memory.
# Epoch 1/100
# 299/299 [==============================] - ETA: 0s - loss: 4.6557 - accuracy: 0.0121
# Epoch 1: val_loss improved from inf to 4.53599, saving model to /tmp/video_classifier
# 299/299 [==============================] - 22s 65ms/step - loss: 4.6557 - accuracy: 0.0121 - val_loss: 4.5360 - val_accuracy: 0.0330
# Epoch 2/100
# 298/299 [============================>.] - ETA: 0s - loss: 4.5653 - accuracy: 0.0221
# Epoch 2: val_loss improved from 4.53599 to 4.44725, saving model to /tmp/video_classifier
# 299/299 [==============================] - 17s 58ms/step - loss: 4.5652 - accuracy: 0.0221 - val_loss: 4.4473 - val_accuracy: 0.1285
# Epoch 3/100
# 299/299 [==============================] - ETA: 0s - loss: 4.4676 - accuracy: 0.0384
# Epoch 3: val_loss improved from 4.44725 to 4.35749, saving model to /tmp/video_classifier
# 299/299 [==============================] - 17s 58ms/step - loss: 4.4676 - accuracy: 0.0384 - val_loss: 4.3575 - val_accuracy: 0.2289
# Epoch 4/100
# 298/299 [============================>.] - ETA: 0s - loss: 4.3762 - accuracy: 0.0654
# Epoch 4: val_loss improved from 4.35749 to 4.26474, saving model to /tmp/video_classifier
# 299/299 [==============================] - 17s 58ms/step - loss: 4.3761 - accuracy: 0.0655 - val_loss: 4.2647 - val_accuracy: 0.3122
# Epoch 5/100
# 299/299 [==============================] - ETA: 0s - loss: 4.2790 - accuracy: 0.1031
# Epoch 5: val_loss improved from 4.26474 to 4.16810, saving model to /tmp/video_classifier
# 299/299 [==============================] - 17s 58ms/step - loss: 4.2790 - accuracy: 0.1031 - val_loss: 4.1681 - val_accuracy: 0.3709
# Epoch 6/100
# 299/299 [==============================] - ETA: 0s - loss: 4.1746 - accuracy: 0.1483
# Epoch 6: val_loss improved from 4.16810 to 4.06642, saving model to /tmp/video_classifier
# 299/299 [==============================] - 17s 59ms/step - loss: 4.1746 - accuracy: 0.1483 - val_loss: 4.0664 - val_accuracy: 0.4073
# Epoch 7/100
# 298/299 [============================>.] - ETA: 0s - loss: 4.0734 - accuracy: 0.1884
# Epoch 7: val_loss improved from 4.06642 to 3.95755, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 60ms/step - loss: 4.0733 - accuracy: 0.1885 - val_loss: 3.9575 - val_accuracy: 0.4285
# Epoch 8/100
# 298/299 [============================>.] - ETA: 0s - loss: 3.9626 - accuracy: 0.2404
# Epoch 8: val_loss improved from 3.95755 to 3.84187, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 3.9626 - accuracy: 0.2403 - val_loss: 3.8419 - val_accuracy: 0.4404
# Epoch 9/100
# 298/299 [============================>.] - ETA: 0s - loss: 3.8414 - accuracy: 0.2854
# Epoch 9: val_loss improved from 3.84187 to 3.71804, saving model to /tmp/video_classifier
# 299/299 [==============================] - 19s 62ms/step - loss: 3.8412 - accuracy: 0.2855 - val_loss: 3.7180 - val_accuracy: 0.4512
# Epoch 10/100
# 298/299 [============================>.] - ETA: 0s - loss: 3.7176 - accuracy: 0.3273
# Epoch 10: val_loss improved from 3.71804 to 3.58728, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 3.7175 - accuracy: 0.3274 - val_loss: 3.5873 - val_accuracy: 0.4592
# Epoch 11/100
# 298/299 [============================>.] - ETA: 0s - loss: 3.5717 - accuracy: 0.3652
# Epoch 11: val_loss improved from 3.58728 to 3.45058, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 3.5717 - accuracy: 0.3652 - val_loss: 3.4506 - val_accuracy: 0.4700
# Epoch 12/100
# 298/299 [============================>.] - ETA: 0s - loss: 3.4407 - accuracy: 0.3925
# Epoch 12: val_loss improved from 3.45058 to 3.30905, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 3.4405 - accuracy: 0.3925 - val_loss: 3.3091 - val_accuracy: 0.4761
# Epoch 13/100
# 298/299 [============================>.] - ETA: 0s - loss: 3.2984 - accuracy: 0.4125
# Epoch 13: val_loss improved from 3.30905 to 3.16520, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 3.2984 - accuracy: 0.4126 - val_loss: 3.1652 - val_accuracy: 0.4861
# Epoch 14/100
# 298/299 [============================>.] - ETA: 0s - loss: 3.1407 - accuracy: 0.4436
# Epoch 14: val_loss improved from 3.16520 to 3.01997, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 3.1407 - accuracy: 0.4436 - val_loss: 3.0200 - val_accuracy: 0.4922
# Epoch 15/100
# 298/299 [============================>.] - ETA: 0s - loss: 2.9876 - accuracy: 0.4704
# Epoch 15: val_loss improved from 3.01997 to 2.87449, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 2.9874 - accuracy: 0.4705 - val_loss: 2.8745 - val_accuracy: 0.5017
# Epoch 16/100
# 298/299 [============================>.] - ETA: 0s - loss: 2.8394 - accuracy: 0.4883
# Epoch 16: val_loss improved from 2.87449 to 2.73242, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 2.8396 - accuracy: 0.4882 - val_loss: 2.7324 - val_accuracy: 0.5065
# Epoch 17/100
# 298/299 [============================>.] - ETA: 0s - loss: 2.6864 - accuracy: 0.5142
# Epoch 17: val_loss improved from 2.73242 to 2.58982, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 2.6863 - accuracy: 0.5142 - val_loss: 2.5898 - val_accuracy: 0.5208
# Epoch 18/100
# 298/299 [============================>.] - ETA: 0s - loss: 2.5283 - accuracy: 0.5348
# Epoch 18: val_loss improved from 2.58982 to 2.45232, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 2.5281 - accuracy: 0.5349 - val_loss: 2.4523 - val_accuracy: 0.5342
# Epoch 19/100
# 298/299 [============================>.] - ETA: 0s - loss: 2.3856 - accuracy: 0.5575
# Epoch 19: val_loss improved from 2.45232 to 2.32002, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 2.3857 - accuracy: 0.5574 - val_loss: 2.3200 - val_accuracy: 0.5456
# Epoch 20/100
# 298/299 [============================>.] - ETA: 0s - loss: 2.2445 - accuracy: 0.5817
# Epoch 20: val_loss improved from 2.32002 to 2.19474, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 2.2443 - accuracy: 0.5817 - val_loss: 2.1947 - val_accuracy: 0.5588
# Epoch 21/100
# 298/299 [============================>.] - ETA: 0s - loss: 2.1011 - accuracy: 0.6035
# Epoch 21: val_loss improved from 2.19474 to 2.07820, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 2.1011 - accuracy: 0.6034 - val_loss: 2.0782 - val_accuracy: 0.5757
# Epoch 22/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.9714 - accuracy: 0.6210
# Epoch 22: val_loss improved from 2.07820 to 1.96732, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 1.9715 - accuracy: 0.6211 - val_loss: 1.9673 - val_accuracy: 0.5887
# Epoch 23/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.8476 - accuracy: 0.6331
# Epoch 23: val_loss improved from 1.96732 to 1.86569, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 1.8476 - accuracy: 0.6331 - val_loss: 1.8657 - val_accuracy: 0.6027
# Epoch 24/100
# 299/299 [==============================] - ETA: 0s - loss: 1.7216 - accuracy: 0.6570
# Epoch 24: val_loss improved from 1.86569 to 1.77009, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 1.7216 - accuracy: 0.6570 - val_loss: 1.7701 - val_accuracy: 0.6090
# Epoch 25/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.6060 - accuracy: 0.6736
# Epoch 25: val_loss improved from 1.77009 to 1.68571, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 1.6059 - accuracy: 0.6736 - val_loss: 1.6857 - val_accuracy: 0.6215
# Epoch 26/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.4980 - accuracy: 0.6904
# Epoch 26: val_loss improved from 1.68571 to 1.61076, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 1.4980 - accuracy: 0.6905 - val_loss: 1.6108 - val_accuracy: 0.6244
# Epoch 27/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.4057 - accuracy: 0.7053
# Epoch 27: val_loss improved from 1.61076 to 1.53949, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 1.4056 - accuracy: 0.7054 - val_loss: 1.5395 - val_accuracy: 0.6384
# Epoch 28/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.3118 - accuracy: 0.7190
# Epoch 28: val_loss improved from 1.53949 to 1.47555, saving model to /tmp/video_classifier
# 299/299 [==============================] - 19s 62ms/step - loss: 1.3117 - accuracy: 0.7190 - val_loss: 1.4756 - val_accuracy: 0.6429
# Epoch 29/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.2131 - accuracy: 0.7393
# Epoch 29: val_loss improved from 1.47555 to 1.42128, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 1.2130 - accuracy: 0.7393 - val_loss: 1.4213 - val_accuracy: 0.6524
# Epoch 30/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.1457 - accuracy: 0.7527
# Epoch 30: val_loss improved from 1.42128 to 1.37508, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 1.1457 - accuracy: 0.7528 - val_loss: 1.3751 - val_accuracy: 0.6577
# Epoch 31/100
# 298/299 [============================>.] - ETA: 0s - loss: 1.0645 - accuracy: 0.7636
# Epoch 31: val_loss improved from 1.37508 to 1.32364, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 1.0644 - accuracy: 0.7637 - val_loss: 1.3236 - val_accuracy: 0.6646
# Epoch 32/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.9927 - accuracy: 0.7746
# Epoch 32: val_loss improved from 1.32364 to 1.28469, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 0.9927 - accuracy: 0.7747 - val_loss: 1.2847 - val_accuracy: 0.6688
# Epoch 33/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.9227 - accuracy: 0.7910
# Epoch 33: val_loss improved from 1.28469 to 1.25266, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 0.9228 - accuracy: 0.7909 - val_loss: 1.2527 - val_accuracy: 0.6698
# Epoch 34/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.8679 - accuracy: 0.7977
# Epoch 34: val_loss improved from 1.25266 to 1.22365, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 60ms/step - loss: 0.8679 - accuracy: 0.7977 - val_loss: 1.2236 - val_accuracy: 0.6778
# Epoch 35/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.8076 - accuracy: 0.8107
# Epoch 35: val_loss improved from 1.22365 to 1.18844, saving model to /tmp/video_classifier
# 299/299 [==============================] - 19s 63ms/step - loss: 0.8076 - accuracy: 0.8107 - val_loss: 1.1884 - val_accuracy: 0.6838
# Epoch 36/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.7557 - accuracy: 0.8192
# Epoch 36: val_loss improved from 1.18844 to 1.15644, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 0.7556 - accuracy: 0.8192 - val_loss: 1.1564 - val_accuracy: 0.6897
# Epoch 37/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.6929 - accuracy: 0.8350
# Epoch 37: val_loss did not improve from 1.15644
# 299/299 [==============================] - 18s 60ms/step - loss: 0.6930 - accuracy: 0.8351 - val_loss: 1.1727 - val_accuracy: 0.6841
# Epoch 38/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.6436 - accuracy: 0.8473
# Epoch 38: val_loss improved from 1.15644 to 1.11370, saving model to /tmp/video_classifier
# 299/299 [==============================] - 19s 62ms/step - loss: 0.6436 - accuracy: 0.8473 - val_loss: 1.1137 - val_accuracy: 0.6992
# Epoch 39/100
# 299/299 [==============================] - ETA: 0s - loss: 0.5909 - accuracy: 0.8598
# Epoch 39: val_loss improved from 1.11370 to 1.09565, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 0.5909 - accuracy: 0.8598 - val_loss: 1.0957 - val_accuracy: 0.7042
# Epoch 40/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.5464 - accuracy: 0.8680
# Epoch 40: val_loss improved from 1.09565 to 1.08073, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 0.5463 - accuracy: 0.8680 - val_loss: 1.0807 - val_accuracy: 0.7034
# Epoch 41/100
# 299/299 [==============================] - ETA: 0s - loss: 0.5034 - accuracy: 0.8822
# Epoch 41: val_loss improved from 1.08073 to 1.07346, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 0.5034 - accuracy: 0.8822 - val_loss: 1.0735 - val_accuracy: 0.7082
# Epoch 42/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.4606 - accuracy: 0.8908
# Epoch 42: val_loss did not improve from 1.07346
# 299/299 [==============================] - 18s 61ms/step - loss: 0.4607 - accuracy: 0.8908 - val_loss: 1.0805 - val_accuracy: 0.7082
# Epoch 43/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.4289 - accuracy: 0.8992
# Epoch 43: val_loss improved from 1.07346 to 1.06649, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 0.4289 - accuracy: 0.8992 - val_loss: 1.0665 - val_accuracy: 0.7100
# Epoch 44/100
# 299/299 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.9079
# Epoch 44: val_loss improved from 1.06649 to 1.05149, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 0.3927 - accuracy: 0.9079 - val_loss: 1.0515 - val_accuracy: 0.7119
# Epoch 45/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.3590 - accuracy: 0.9181
# Epoch 45: val_loss improved from 1.05149 to 1.03746, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 62ms/step - loss: 0.3589 - accuracy: 0.9181 - val_loss: 1.0375 - val_accuracy: 0.7169
# Epoch 46/100
# 299/299 [==============================] - ETA: 0s - loss: 0.3279 - accuracy: 0.9261
# Epoch 46: val_loss improved from 1.03746 to 1.03547, saving model to /tmp/video_classifier
# 299/299 [==============================] - 18s 61ms/step - loss: 0.3279 - accuracy: 0.9261 - val_loss: 1.0355 - val_accuracy: 0.7182
# Epoch 47/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.2992 - accuracy: 0.9344
# Epoch 47: val_loss improved from 1.03547 to 1.03244, saving model to /tmp/video_classifier
# 299/299 [==============================] - 19s 62ms/step - loss: 0.2992 - accuracy: 0.9344 - val_loss: 1.0324 - val_accuracy: 0.7206
# Epoch 48/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.2767 - accuracy: 0.9380
# Epoch 48: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.2767 - accuracy: 0.9380 - val_loss: 1.0469 - val_accuracy: 0.7172
# Epoch 49/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.2510 - accuracy: 0.9434
# Epoch 49: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.2510 - accuracy: 0.9434 - val_loss: 1.0525 - val_accuracy: 0.7224
# Epoch 50/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.2277 - accuracy: 0.9505
# Epoch 50: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.2277 - accuracy: 0.9505 - val_loss: 1.0368 - val_accuracy: 0.7190
# Epoch 51/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.2100 - accuracy: 0.9577
# Epoch 51: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.2099 - accuracy: 0.9577 - val_loss: 1.0340 - val_accuracy: 0.7206
# Epoch 52/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.1936 - accuracy: 0.9625
# Epoch 52: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.1936 - accuracy: 0.9625 - val_loss: 1.0373 - val_accuracy: 0.7243
# Epoch 53/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9617
# Epoch 53: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 62ms/step - loss: 0.1803 - accuracy: 0.9617 - val_loss: 1.0416 - val_accuracy: 0.7240
# Epoch 54/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.1611 - accuracy: 0.9693
# Epoch 54: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.1611 - accuracy: 0.9693 - val_loss: 1.0830 - val_accuracy: 0.7164
# Epoch 55/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.1460 - accuracy: 0.9742
# Epoch 55: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.1459 - accuracy: 0.9742 - val_loss: 1.0484 - val_accuracy: 0.7256
# Epoch 56/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.1333 - accuracy: 0.9775
# Epoch 56: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.1333 - accuracy: 0.9775 - val_loss: 1.0464 - val_accuracy: 0.7280
# Epoch 57/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.1206 - accuracy: 0.9813
# Epoch 57: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.1205 - accuracy: 0.9813 - val_loss: 1.0460 - val_accuracy: 0.7309
# Epoch 58/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.1124 - accuracy: 0.9809
# Epoch 58: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.1124 - accuracy: 0.9809 - val_loss: 1.0543 - val_accuracy: 0.7291
# Epoch 59/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.9830
# Epoch 59: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.1053 - accuracy: 0.9830 - val_loss: 1.0532 - val_accuracy: 0.7296
# Epoch 60/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0962 - accuracy: 0.9863
# Epoch 60: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0962 - accuracy: 0.9863 - val_loss: 1.0599 - val_accuracy: 0.7314
# Epoch 61/100
# 299/299 [==============================] - ETA: 0s - loss: 0.0874 - accuracy: 0.9889
# Epoch 61: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0874 - accuracy: 0.9889 - val_loss: 1.0613 - val_accuracy: 0.7330
# Epoch 62/100
# 299/299 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9884
# Epoch 62: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0811 - accuracy: 0.9884 - val_loss: 1.0628 - val_accuracy: 0.7328
# Epoch 63/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0755 - accuracy: 0.9897
# Epoch 63: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0755 - accuracy: 0.9897 - val_loss: 1.0686 - val_accuracy: 0.7312
# Epoch 64/100
# 299/299 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9919
# Epoch 64: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0696 - accuracy: 0.9919 - val_loss: 1.0673 - val_accuracy: 0.7312
# Epoch 65/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0637 - accuracy: 0.9935
# Epoch 65: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0637 - accuracy: 0.9935 - val_loss: 1.0830 - val_accuracy: 0.7349
# Epoch 66/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0595 - accuracy: 0.9935
# Epoch 66: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0595 - accuracy: 0.9935 - val_loss: 1.0799 - val_accuracy: 0.7272
# Epoch 67/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0550 - accuracy: 0.9948
# Epoch 67: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0551 - accuracy: 0.9948 - val_loss: 1.3194 - val_accuracy: 0.6817
# Epoch 68/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0587 - accuracy: 0.9941
# Epoch 68: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0587 - accuracy: 0.9941 - val_loss: 1.0809 - val_accuracy: 0.7330
# Epoch 69/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0481 - accuracy: 0.9956
# Epoch 69: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0481 - accuracy: 0.9956 - val_loss: 1.0783 - val_accuracy: 0.7349
# Epoch 70/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9971
# Epoch 70: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0458 - accuracy: 0.9971 - val_loss: 1.0899 - val_accuracy: 0.7359
# Epoch 71/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9975
# Epoch 71: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0414 - accuracy: 0.9975 - val_loss: 1.0979 - val_accuracy: 0.7343
# Epoch 72/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 0.9979
# Epoch 72: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0392 - accuracy: 0.9979 - val_loss: 1.1163 - val_accuracy: 0.7328
# Epoch 73/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9979
# Epoch 73: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0376 - accuracy: 0.9979 - val_loss: 1.1064 - val_accuracy: 0.7351
# Epoch 74/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9982
# Epoch 74: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0346 - accuracy: 0.9982 - val_loss: 1.1030 - val_accuracy: 0.7346
# Epoch 75/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9980
# Epoch 75: val_loss did not improve from 1.03244
# 299/299 [==============================] - 19s 62ms/step - loss: 0.0336 - accuracy: 0.9980 - val_loss: 1.1032 - val_accuracy: 0.7328
# Epoch 76/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9982
# Epoch 76: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0319 - accuracy: 0.9982 - val_loss: 1.1153 - val_accuracy: 0.7325
# Epoch 77/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9986
# Epoch 77: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0296 - accuracy: 0.9986 - val_loss: 1.1141 - val_accuracy: 0.7341
# Epoch 78/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0276 - accuracy: 0.9991
# Epoch 78: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0276 - accuracy: 0.9991 - val_loss: 1.1113 - val_accuracy: 0.7351
# Epoch 79/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9992
# Epoch 79: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0258 - accuracy: 0.9992 - val_loss: 1.1180 - val_accuracy: 0.7333
# Epoch 80/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9993
# Epoch 80: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0254 - accuracy: 0.9993 - val_loss: 1.1177 - val_accuracy: 0.7333
# Epoch 81/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9993
# Epoch 81: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0234 - accuracy: 0.9993 - val_loss: 1.1207 - val_accuracy: 0.7341
# Epoch 82/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9995
# Epoch 82: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0232 - accuracy: 0.9995 - val_loss: 1.1259 - val_accuracy: 0.7338
# Epoch 83/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0215 - accuracy: 0.9997
# Epoch 83: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0215 - accuracy: 0.9997 - val_loss: 1.1233 - val_accuracy: 0.7365
# Epoch 84/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9996
# Epoch 84: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0206 - accuracy: 0.9996 - val_loss: 1.1303 - val_accuracy: 0.7338
# Epoch 85/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9993
# Epoch 85: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0202 - accuracy: 0.9993 - val_loss: 1.1425 - val_accuracy: 0.7362
# Epoch 86/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 0.9995
# Epoch 86: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0193 - accuracy: 0.9995 - val_loss: 1.1315 - val_accuracy: 0.7370
# Epoch 87/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9998
# Epoch 87: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0186 - accuracy: 0.9998 - val_loss: 1.1435 - val_accuracy: 0.7367
# Epoch 88/100
# 299/299 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9998
# Epoch 88: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0177 - accuracy: 0.9998 - val_loss: 1.1386 - val_accuracy: 0.7354
# Epoch 89/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0168 - accuracy: 0.9997
# Epoch 89: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0168 - accuracy: 0.9997 - val_loss: 1.1429 - val_accuracy: 0.7359
# Epoch 90/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9999
# Epoch 90: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0160 - accuracy: 0.9999 - val_loss: 1.1412 - val_accuracy: 0.7357
# Epoch 91/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9997
# Epoch 91: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0160 - accuracy: 0.9997 - val_loss: 1.1490 - val_accuracy: 0.7357
# Epoch 92/100
# 299/299 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9996
# Epoch 92: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0154 - accuracy: 0.9996 - val_loss: 1.1545 - val_accuracy: 0.7365
# Epoch 93/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 93: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 1.1457 - val_accuracy: 0.7380
# Epoch 94/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0139 - accuracy: 0.9998
# Epoch 94: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0139 - accuracy: 0.9998 - val_loss: 1.1503 - val_accuracy: 0.7362
# Epoch 95/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0137 - accuracy: 0.9998
# Epoch 95: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0137 - accuracy: 0.9998 - val_loss: 1.1553 - val_accuracy: 0.7386
# Epoch 96/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 96: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.1539 - val_accuracy: 0.7351
# Epoch 97/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9998
# Epoch 97: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0127 - accuracy: 0.9998 - val_loss: 1.1576 - val_accuracy: 0.7362
# Epoch 98/100
# 299/299 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 98: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 60ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.1539 - val_accuracy: 0.7383
# Epoch 99/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9999
# Epoch 99: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0118 - accuracy: 0.9999 - val_loss: 1.1539 - val_accuracy: 0.7394
# Epoch 100/100
# 298/299 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 100: val_loss did not improve from 1.03244
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.1633 - val_accuracy: 0.7383
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 69>()
#      64     print(f"Test accuracy: {round(accuracy * 100, 2)}%")
#      66     return history, seq_model
# ---> 69 d_run_experiment()
#
# Input In [6], in d_run_experiment()
#      47 seq_model.compile(
#      48     loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"]
#      49 )
#      51 history = seq_model.fit(
#      52     [d_train_data[0], d_train_data[1]],
#      53     d_train_labels,
#    (...)
#      59     callbacks=[checkpoint],
#      60 )
# ---> 62 seq_model.load_weights(filepath)
#      63 _, accuracy = seq_model.evaluate([d_test_data[0], d_test_data[1]], d_test_labels)
#      64 print(f"Test accuracy: {round(accuracy * 100, 2)}%")
#
# File ~/miniconda3/envs/ar/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/miniconda3/envs/ar/lib/python3.9/site-packages/tensorflow/python/framework/tensor_shape.py:1167, in TensorShape.assert_is_compatible_with(self, other)
#    1155 """Raises exception if `self` and `other` do not represent the same shape.
#    1156
#    1157 This method can be used to assert that there exists a shape that both
#    (...)
#    1164   ValueError: If `self` and `other` do not represent the same shape.
#    1165 """
#    1166 if not self.is_compatible_with(other):
# -> 1167   raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
# ValueError: Shapes (1792, 8192) and (1280, 8192) are incompatible

# %%
#lr=0.1 75.76%
#lr=0.01 74.86%
#lr=0.001 73.94%

# %%
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"])
)
# print(label_processor.get_vocabulary())

def get_sequence_model():
    class_vocab = label_processor.get_vocabulary()

    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

    # Refer to the following tutorial to understand the significance of using `mask`:
    # https://keras.io/api/layers/recurrent_layers/gru/
    x = keras.layers.LSTM(2048, return_sequences=False,dropout=0.5)(#16, 512
        frame_features_input, mask=mask_input
    )    
#     x = keras.layers.Bidirectional(keras.layers.LSTM(2048, return_sequences=False,dropout=0.5),merge_mode='concat')(#16, 512
#         frame_features_input, mask=mask_input
#     )
#     x = keras.layers.LSTM(2048)(x)#8, 256
#     x = keras.layers.Dropout(0.1)(x)
    x = keras.layers.Dense(1024)(x)#8, 256
    x = keras.layers.GaussianNoise(0.4)(x)
    x = keras.layers.LeakyReLU(0.1)(x)    
    output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

    rnn_model = keras.Model([frame_features_input, mask_input], output)

#     rnn_model.compile(
#         loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
#     )
    return rnn_model

# Utility for running experiments.
def d_run_experiment():
    filepath = "/tmp/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    seq_model = get_sequence_model()
    print(seq_model.summary())
    

    lr_schedule = keras.callbacks.LearningRateScheduler(
                  lambda epoch: 1e-6 * 10**(4*epoch / 10))
    
    optimizer = keras.optimizers.SGD(lr=1e-3)
    
    seq_model.compile(
        loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"]
    )    
#     seq_model.compile(optimizer=optimizer,
#                       loss='categorical_crossentropy',
#                      metrics=['accuracy'])     
    
    history = seq_model.fit(
        [d_train_data[0], d_train_data[1]],
        d_train_labels,
#         validation_split=0.2,
        validation_data=([d_test_data[0], d_test_data[1]],
        d_test_labels),
        epochs=20,
#         epochs=EPOCHS,
        callbacks=[lr_schedule,checkpoint],
    )

    seq_model.load_weights(filepath)
    _, accuracy = seq_model.evaluate([d_test_data[0], d_test_data[1]], d_test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, seq_model


his, seq = d_run_experiment()

# %%
from matplotlib import pyplot as plt

plt.semilogx(his.history['lr'], his.history['accuracy'])
plt.axis([1e-6, 1, 0, 1])
plt.xlabel('lr')
plt.ylabel('accuracy')
plt.show()
